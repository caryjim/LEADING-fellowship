# %%
import os
os.getcwd()
# Out:
# 'D:\\Documents\\PycharmProjects\\LEADING-RAMP'

# %%
# %run RAMP-Summary.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# D:\Documents\PycharmProjects\LEADING-RAMP\RAMP-Summary.py in <module>
#     509 # Rewrite code with os.path.join to read in csv file plus path correctly
#     510 #ir_info = pd.read_csv('../ir_data/RAMP_IR_base_info.csv')
# --> 511 ir_info = pd.read_csv(os.path.join(data_dir+r'RAMP_IR_base_info.csv'))
#     512
#     513 # Define the columns that for the output data frame and file.
#
# ...
